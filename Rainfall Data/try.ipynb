# %%
import pandas as pd

# %%
df = pd.read_excel("Barot_2.xls")
dan=pd.read_excel("Dhangsidhar Mandi.xls")
Kandhi=pd.read_excel("Kandhi_1.xls")

# %%
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df
# Out:
#                    Date(IST)  \
# 0     01/06/2023 02:00:00.00
# 1     01/06/2023 05:00:00.00
# 2     01/06/2023 06:00:00.00
# 3     01/06/2023 07:00:00.00
# 4     01/06/2023 08:00:00.00
# ...                      ...
# 9833  23/08/2024 02:00:00.00
# 9834  23/08/2024 03:00:00.00
# 9835  23/08/2024 05:00:00.00
# 9836  23/08/2024 10:00:00.00
# 9837  23/08/2024 11:00:00.00
#
#       Station Name: Barot_2\nStation Code: 73A09438\nState: Himachal Pradesh\nDistrict: MANDI\nTehsil: -\nBlock: \nVillage: \nParameter: GPC(GPRS-Rain acumm (Daily))-mm  \
# 0                                                  34.0
# 1                                                  34.0
# 2                                                  35.0
# 3                                                  35.0
# 4                                                  35.0
# ...                                                 ...
# 9833                                                1.0
# ...

# %%
df.to_csv("barot_mod.csv")
dan.to_csv("Dhangsidhar_Mandi_mod.csv")
Kandhi.to_csv("Kandhi_mod.csv")

# %%
df = pd.read_csv('Dhangsidhar_Mandi_luv.csv')
df.head()
# Out:
#                      Date  MKC  rain
# 0  28/01/2023 14:00:00.00  0.0   0.0
# 1  15/09/2023 13:23:00.00  0.0   0.0
# 2  15/09/2023 14:00:00.00  0.0   0.0
# 3  15/09/2023 15:00:00.00  0.0   0.0
# 4  16/09/2023 10:33:00.00  2.0   2.0

# %%
df.to_csv()
# Out:
# ',Date,MKC,rain\r\n0,28/01/2023 14:00:00.00,0.0,0.0\r\n1,15/09/2023 13:23:00.00,0.0,0.0\r\n2,15/09/2023 14:00:00.00,0.0,0.0\r\n3,15/09/2023 15:00:00.00,0.0,0.0\r\n4,16/09/2023 10:33:00.00,2.0,2.0\r\n5,16/09/2023 11:00:00.00,2.0,2.0\r\n6,16/09/2023 12:00:00.00,2.0,0.0\r\n7,16/09/2023 13:00:00.00,2.0,0.0\r\n8,16/09/2023 14:00:00.00,2.0,0.0\r\n9,16/09/2023 15:00:00.00,2.0,0.0\r\n10,16/09/2023 16:00:00.00,2.0,0.0\r\n11,16/09/2023 17:00:00.00,2.0,0.0\r\n12,16/09/2023 18:00:00.00,2.0,0.0\r\n13,16/09/2023 19:00:00.00,2.0,0.0\r\n14,16/09/2023 20:00:00.00,2.0,0.0\r\n15,16/09/2023 21:00:00.00,2.0,0.0\r\n16,16/09/2023 22:00:00.00,2.0,0.0\r\n17,16/09/2023 23:00:00.00,2.0,0.0\r\n18,17/09/2023 00:00:00.00,2.0,0.0\r\n19,17/09/2023 01:00:00.00,2.0,0.0\r\n20,17/09/2023 02:00:00.00,2.0,0.0\r\n21,17/09/2023 03:00:00.00,2.0,0.0\r\n22,17/09/2023 04:00:00.00,2.0,0.0\r\n23,17/09/2023 05:00:00.00,2.0,0.0\r\n24,17/09/2023 06:00:00.00,2.0,0.0\r\n25,17/09/2023 07:00:00.00,2.0,0.0\r\n26,17/09/2023 08:00:00.00,2
# ...
